# %%
from langchain_core.messages import AIMessage, HumanMessage
from langchain_google_vertexai.vision_models import VertexAIImageGeneratorChat

# %%
from google.oauth2 import service_account
import vertexai

# Use the full path to your service account JSON
credentials = service_account.Credentials.from_service_account_file(
    "langgraph-443714-984075df4fa2.json"
)

# Initialize Vertex AI with specific credentials and project
vertexai.init(
    project='langgraph-443714', 
    location='us-central1',
    credentials=credentials
)

# %%
#Hay que habilitar el servicio de Vertex AI en la consola de Google Cloud 
#https://console.developers.google.com/apis/api/aiplatform.googleapis.com/overview?project=385545152536

#Luego ejecutar esto 
import vertexai
vertexai.init(project='385545152536')

#if at some point decide to use dalle
#https://www.youtube.com/watch?v=2zNiRGE5TUM&ab_channel=YeyuLab

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'langgraph-443714-984075df4fa2.json'
os.environ['GCLOUD_PROJECT'] = 'langgraph-443714'

# %%
# Create Image Gentation model Object
generator = VertexAIImageGeneratorChat()

messages = [HumanMessage(content=["a cat at the beach"])]
response = generator.invoke(messages)
# To view the generated Image
generated_image = response.content[0]
import base64
import io

from PIL import Image

# Parse response object to get base64 string for image
img_base64 = generated_image["image_url"]["url"].split(",")[-1]

# Convert base64 string to Image
img = Image.open(io.BytesIO(base64.decodebytes(bytes(img_base64, "utf-8"))))

# view Image
img
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Cell In[17], line 5
#       2 generator = VertexAIImageGeneratorChat()
#       4 messages = [HumanMessage(content=["a cat at the beach"])]
# ----> 5 response = generator.invoke(messages)
#       6 # To view the generated Image
#       7 generated_image = response.content[0]
#
# File c:\Users\rios1\LangGraphAgentsTest\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
# ...
